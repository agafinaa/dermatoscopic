# %%
# !pip install segment-anything
# Out:
# Requirement already satisfied: segment-anything in /usr/local/lib/python3.11/dist-packages (1.0)

# %%
import torch
import pandas as pd
import numpy as np
import cv2
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
from transformers import ViTForImageClassification, ViTFeatureExtractor
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator
from google.colab import drive
import os
from sklearn.model_selection import train_test_split

# %%
drive.mount('/content/drive')
metadata_path = '/content/drive/MyDrive/Курсовая/HAM10000_metadata.tab'
image_folder_1 = '/content/drive/MyDrive/Курсовая/HAM10000_images_part_1/'
image_folder_2 = '/content/drive/MyDrive/Курсовая/HAM10000_images_part_2/'
processed_folder = '/content/drive/MyDrive//Курсовая/HAM10000_preprocessed/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv(metadata_path, sep='\t', header=None)
df.columns = ['lesion_id', 'image_id', 'diagnosis', 'type_of_diagnostic', 'age', 'sex', 'localization', 'source']
df
# Out:
#          lesion_id      image_id diagnosis type_of_diagnostic   age     sex  \
# 0      HAM_0000118  ISIC_0027419       bkl              histo  80.0    male
# 1      HAM_0000118  ISIC_0025030       bkl              histo  80.0    male
# 2      HAM_0002730  ISIC_0026769       bkl              histo  80.0    male
# 3      HAM_0002730  ISIC_0025661       bkl              histo  80.0    male
# 4      HAM_0001466  ISIC_0031633       bkl              histo  75.0    male
# ...            ...           ...       ...                ...   ...     ...
# 10010  HAM_0002867  ISIC_0033084     akiec              histo  40.0    male
# 10011  HAM_0002867  ISIC_0033550     akiec              histo  40.0    male
# 10012  HAM_0002867  ISIC_0033536     akiec              histo  40.0    male
# 10013  HAM_0000239  ISIC_0032854     akiec              histo  80.0    male
# 10014  HAM_0003521  ISIC_0032258       mel              histo  70.0  female
#
#       localization        source
# 0            scalp  vidir_modern
# 1            scalp  vidir_modern
# 2            scalp  vidir_modern
# 3            scalp  vidir_modern
# 4              ear  vidir_modern
# ...            ...           ...
# 10010      abdomen  vidir_modern
# 10011      abdomen  vidir_modern
# 10012      abdomen  vidir_modern
# 10013         face  vidir_modern
# 10014         back  vidir_modern
#
# [10015 rows x 8 columns]

# %%
df.nunique()
# Out:
# lesion_id              7470
# image_id              10015
# diagnosis                 7
# type_of_diagnostic        4
# age                      18
# sex                       3
# localization             15
# source                    4
# dtype: int64

# %%
df['diagnosis'].unique()
# Out:
# array(['bkl', 'nv', 'df', 'mel', 'vasc', 'bcc', 'akiec'], dtype=object)

# %% [markdown]
# bkl — Benign keratosis-like lesions (доброкачественный кератоз)
#
# nv — Melanocytic nevus (меланоцитарный невус)
#
# df — Dermatofibroma (дерматофиброма)
#
# mel — Melanoma (меланома)
#
# vasc — Vascular lesions (сосудистые поражения)
#
# bcc — Basal cell carcinoma (базально-клеточная карцинома)
#
# akiec — Actinic keratosis and intraepithelial carcinoma (актинический кератоз и внутрикожная карцинома)

# %%
df['image_path'] = df['image_id'].apply(lambda x: image_folder_1 + x + '.jpg' if os.path.exists(image_folder_1 + x + '.jpg') else image_folder_2 + x + '.jpg')

# %%
df
# Out:
#          lesion_id      image_id diagnosis type_of_diagnostic   age     sex  \
# 0      HAM_0000118  ISIC_0027419       bkl              histo  80.0    male
# 1      HAM_0000118  ISIC_0025030       bkl              histo  80.0    male
# 2      HAM_0002730  ISIC_0026769       bkl              histo  80.0    male
# 3      HAM_0002730  ISIC_0025661       bkl              histo  80.0    male
# 4      HAM_0001466  ISIC_0031633       bkl              histo  75.0    male
# ...            ...           ...       ...                ...   ...     ...
# 10010  HAM_0002867  ISIC_0033084     akiec              histo  40.0    male
# 10011  HAM_0002867  ISIC_0033550     akiec              histo  40.0    male
# 10012  HAM_0002867  ISIC_0033536     akiec              histo  40.0    male
# 10013  HAM_0000239  ISIC_0032854     akiec              histo  80.0    male
# 10014  HAM_0003521  ISIC_0032258       mel              histo  70.0  female
#
#       localization        source  \
# 0            scalp  vidir_modern
# 1            scalp  vidir_modern
# 2            scalp  vidir_modern
# 3            scalp  vidir_modern
# 4              ear  vidir_modern
# ...            ...           ...
# 10010      abdomen  vidir_modern
# 10011      abdomen  vidir_modern
# 10012      abdomen  vidir_modern
# 10013         face  vidir_modern
# 10014         back  vidir_modern
#
#                                               image_path
# 0      /content/drive/MyDrive/Курсовая/HAM10000_image...
# 1      /content/drive/MyDrive/Курсовая/HAM10000_image...
# 2      /content/drive/MyDrive/Курсовая/HAM10000_image...
# 3      /content/drive/MyDrive/Курсовая/HAM10000_image...
# 4      /content/drive/MyDrive/Курсовая/HAM10000_image...
# ...                                                  ...
# 10010  /content/drive/MyDrive/Курсовая/HAM10000_image...
# 10011  /content/drive/MyDrive/Курсовая/HAM10000_image...
# 10012  /content/drive/MyDrive/Курсовая/HAM10000_image...
# 10013  /content/drive/MyDrive/Курсовая/HAM10000_image...
# 10014  /content/drive/MyDrive/Курсовая/HAM10000_image...
#
# [10015 rows x 9 columns]

# %%
# закодируем диагнозы цифрами
class_names = df['diagnosis'].unique()
class_to_idx = {class_name: idx for idx, class_name in enumerate(class_names)}
df['label_diagnosis'] = df['diagnosis'].map(class_to_idx)
df
# Out:
#          lesion_id      image_id diagnosis type_of_diagnostic   age     sex  \
# 0      HAM_0000118  ISIC_0027419       bkl              histo  80.0    male
# 1      HAM_0000118  ISIC_0025030       bkl              histo  80.0    male
# 2      HAM_0002730  ISIC_0026769       bkl              histo  80.0    male
# 3      HAM_0002730  ISIC_0025661       bkl              histo  80.0    male
# 4      HAM_0001466  ISIC_0031633       bkl              histo  75.0    male
# ...            ...           ...       ...                ...   ...     ...
# 10010  HAM_0002867  ISIC_0033084     akiec              histo  40.0    male
# 10011  HAM_0002867  ISIC_0033550     akiec              histo  40.0    male
# 10012  HAM_0002867  ISIC_0033536     akiec              histo  40.0    male
# 10013  HAM_0000239  ISIC_0032854     akiec              histo  80.0    male
# 10014  HAM_0003521  ISIC_0032258       mel              histo  70.0  female
#
#       localization        source  \
# 0            scalp  vidir_modern
# 1            scalp  vidir_modern
# 2            scalp  vidir_modern
# 3            scalp  vidir_modern
# 4              ear  vidir_modern
# ...            ...           ...
# 10010      abdomen  vidir_modern
# 10011      abdomen  vidir_modern
# 10012      abdomen  vidir_modern
# 10013         face  vidir_modern
# 10014         back  vidir_modern
#
#                                               image_path  label_diagnosis
# 0      /content/drive/MyDrive/Курсовая/HAM10000_image...                0
# 1      /content/drive/MyDrive/Курсовая/HAM10000_image...                0
# 2      /content/drive/MyDrive/Курсовая/HAM10000_image...                0
# 3      /content/drive/MyDrive/Курсовая/HAM10000_image...                0
# 4      /content/drive/MyDrive/Курсовая/HAM10000_image...                0
# ...                                                  ...              ...
# 10010  /content/drive/MyDrive/Курсовая/HAM10000_image...                6
# 10011  /content/drive/MyDrive/Курсовая/HAM10000_image...                6
# 10012  /content/drive/MyDrive/Курсовая/HAM10000_image...                6
# 10013  /content/drive/MyDrive/Курсовая/HAM10000_image...                6
# 10014  /content/drive/MyDrive/Курсовая/HAM10000_image...                3
#
# [10015 rows x 10 columns]

# %%
df.drop(columns=['diagnosis'], inplace=True)

# %%
class_to_idx  # соответствие диагноза лейблу
# Out:
# {'bkl': 0, 'nv': 1, 'df': 2, 'mel': 3, 'vasc': 4, 'bcc': 5, 'akiec': 6}

# %%
train_df, tmp_df = train_test_split(df, test_size=0.3, stratify=df['label_diagnosis'], random_state=42)
val_df, test_df = train_test_split(tmp_df, test_size=0.5, stratify=tmp_df['label_diagnosis'], random_state=42)

# %%
print(len(train_df), len(val_df), len(test_df))
# Out:
# 7010 1502 1503

# %%
def segment_image(image_path):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    masks = mask_generator.generate(image)
    return masks

# %%
# уберем пока это
'''def preprocess_and_save_images(dataframe):
    os.makedirs(processed_folder, exist_ok=True)
    for idx, row in dataframe.iterrows():
        img_path = image_folder_1 + row['image_id'] + '.jpg' if os.path.exists(image_folder_1 + row['image_id'] + '.jpg') else image_folder_2 + row['image_id'] + '.jpg'
        masks = segment_image(img_path)
        image = cv2.imread(img_path)
        for i, mask in enumerate(masks):
            mask_uint8 = (mask['segmentation'] * 255).astype(np.uint8)
            segmented_image = cv2.bitwise_and(image, image, mask=mask_uint8)
            processed_path = os.path.join(processed_folder, f"{row['image_id']}_mask_{i}.jpg")
            cv2.imwrite(processed_path, segmented_image)

        dataframe.at[idx, 'image_path'] = processed_path


preprocess_and_save_images(df)'''
# Out:
# 'def preprocess_and_save_images(dataframe):\n    os.makedirs(processed_folder, exist_ok=True)\n    for idx, row in dataframe.iterrows():\n        img_path = image_folder_1 + row[\'image_id\'] + \'.jpg\' if os.path.exists(image_folder_1 + row[\'image_id\'] + \'.jpg\') else image_folder_2 + row[\'image_id\'] + \'.jpg\'\n        masks = segment_image(img_path)\n        image = cv2.imread(img_path)\n        for i, mask in enumerate(masks):\n            mask_uint8 = (mask[\'segmentation\'] * 255).astype(np.uint8)\n            segmented_image = cv2.bitwise_and(image, image, mask=mask_uint8)\n            processed_path = os.path.join(processed_folder, f"{row[\'image_id\']}_mask_{i}.jpg")\n            cv2.imwrite(processed_path, segmented_image)\n\n        dataframe.at[idx, \'image_path\'] = processed_path\n\n\npreprocess_and_save_images(df)'

# %%
class SkinLesionDataset(Dataset):
    def __init__(self, dataframe, transform=None):
        self.dataframe = dataframe
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_path = self.dataframe.iloc[idx]['image_path']
        label = self.dataframe.iloc[idx]['label_diagnosis']
        image = Image.open(img_path).convert('RGB')

        if self.transform:
            image = self.transform(image)
        return image, label

transform = transforms.Compose([transforms.Resize((224, 224)),
                                transforms.ToTensor(),
                                transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])])

# %%
train_dataset = SkinLesionDataset(train_df, transform=transform)
val_dataset = SkinLesionDataset(val_df, transform=transform)
test_dataset = SkinLesionDataset(test_df, transform=transform)

# %%
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
'''sam_checkpoint = '/content/drive/MyDrive/Курсовая/sam_vit_h_4b8939.pth'
model_type = 'vit_h'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
sam = sam_model_registry[model_type](checkpoint=sam_checkpoint).to(device)
mask_generator = SamAutomaticMaskGenerator(sam)'''
# Out:
# "sam_checkpoint = '/content/drive/MyDrive/Курсовая/sam_vit_h_4b8939.pth'\nmodel_type = 'vit_h'\ndevice = torch.device('cuda' if torch.cuda.is_available() else 'cpu')\nsam = sam_model_registry[model_type](checkpoint=sam_checkpoint).to(device)\nmask_generator = SamAutomaticMaskGenerator(sam)"

# %%
device
# Out:
# device(type='cuda')

# %%
model_name = 'google/vit-base-patch16-224-in21k'
model = ViTForImageClassification.from_pretrained(model_name, num_labels=len(class_names)).to(device) # предобученный vit
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

def train_model(num_epochs):
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct, total = 0, 0
        for batch_idx, (images, labels) in enumerate(train_dataloader):
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images).logits
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            if batch_idx % 10 == 0:
                print(f'Эпоха {epoch+1}, Батч {batch_idx}/{len(train_dataloader)}, Потери: {running_loss/(batch_idx+1):.4f}')
        print(f'Эпоха {epoch+1}, Средние потери: {running_loss/len(train_dataloader):.4f}, Точность: {100 * correct / total:.2f}%')

train_model(num_epochs=10)
# Out:
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Эпоха 1, Батч 0/220, Потери: 1.7831
# Эпоха 1, Батч 10/220, Потери: 1.3658
# Эпоха 1, Батч 20/220, Потери: 1.2602
# Эпоха 1, Батч 30/220, Потери: 1.1237
# Эпоха 1, Батч 40/220, Потери: 1.0540
# Эпоха 1, Батч 50/220, Потери: 1.0181
# Эпоха 1, Батч 60/220, Потери: 0.9835
# Эпоха 1, Батч 70/220, Потери: 0.9509
# Эпоха 1, Батч 80/220, Потери: 0.9236
# Эпоха 1, Батч 90/220, Потери: 0.9073
# Эпоха 1, Батч 100/220, Потери: 0.8870
# Эпоха 1, Батч 110/220, Потери: 0.8675
# Эпоха 1, Батч 120/220, Потери: 0.8545
# Эпоха 1, Батч 130/220, Потери: 0.8391
# Эпоха 1, Батч 140/220, Потери: 0.8294
# Эпоха 1, Батч 150/220, Потери: 0.8129
# Эпоха 1, Батч 160/220, Потери: 0.7993
# Эпоха 1, Батч 170/220, Потери: 0.7907
# Эпоха 1, Батч 180/220, Потери: 0.7806
# Эпоха 1, Батч 190/220, Потери: 0.7716
# Эпоха 1, Батч 200/220, Потери: 0.7640
# Эпоха 1, Батч 210/220, Потери: 0.7561
# Эпоха 1, Средние потери: 0.7492, Точность: 75.26%
# Эпоха 2, Батч 0/220, Потери: 0.5932
# Эпоха 2, Батч 10/220, Потери: 0.5206
# Эпоха 2, Батч 20/220, Потери: 0.4959
# Эпоха 2, Батч 30/220, Потери: 0.5030
# Эпоха 2, Батч 40/220, Потери: 0.4900
# Эпоха 2, Батч 50/220, Потери: 0.4843
# Эпоха 2, Батч 60/220, Потери: 0.4701
# Эпоха 2, Батч 70/220, Потери: 0.4598
# Эпоха 2, Батч 80/220, Потери: 0.4485
# Эпоха 2, Батч 90/220, Потери: 0.4472
# Эпоха 2, Батч 100/220, Потери: 0.4394
# Эпоха 2, Батч 110/220, Потери: 0.4387
# Эпоха 2, Батч 120/220, Потери: 0.4359
# Эпоха 2, Батч 130/220, Потери: 0.4338
# Эпоха 2, Батч 140/220, Потери: 0.4352
# Эпоха 2, Батч 150/220, Потери: 0.4363
# Эпоха 2, Батч 160/220, Потери: 0.4313
# Эпоха 2, Батч 170/220, Потери: 0.4301
# Эпоха 2, Батч 180/220, Потери: 0.4317
# Эпоха 2, Батч 190/220, Потери: 0.4325
# Эпоха 2, Батч 200/220, Потери: 0.4308
# Эпоха 2, Батч 210/220, Потери: 0.4302
# Эпоха 2, Средние потери: 0.4262, Точность: 85.85%
# Эпоха 3, Батч 0/220, Потери: 0.1664
# Эпоха 3, Батч 10/220, Потери: 0.2734
# Эпоха 3, Батч 20/220, Потери: 0.2564
# Эпоха 3, Батч 30/220, Потери: 0.2574
# Эпоха 3, Батч 40/220, Потери: 0.2766
# Эпоха 3, Батч 50/220, Потери: 0.2689
# Эпоха 3, Батч 60/220, Потери: 0.2627
# Эпоха 3, Батч 70/220, Потери: 0.2573
# Эпоха 3, Батч 80/220, Потери: 0.2516
# Эпоха 3, Батч 90/220, Потери: 0.2468
# Эпоха 3, Батч 100/220, Потери: 0.2456
# Эпоха 3, Батч 110/220, Потери: 0.2443
# Эпоха 3, Батч 120/220, Потери: 0.2477
# Эпоха 3, Батч 130/220, Потери: 0.2478
# Эпоха 3, Батч 140/220, Потери: 0.2531
# Эпоха 3, Батч 150/220, Потери: 0.2610
# Эпоха 3, Батч 160/220, Потери: 0.2610
# Эпоха 3, Батч 170/220, Потери: 0.2580
# Эпоха 3, Батч 180/220, Потери: 0.2576
# Эпоха 3, Батч 190/220, Потери: 0.2536
# Эпоха 3, Батч 200/220, Потери: 0.2530
# Эпоха 3, Батч 210/220, Потери: 0.2520
# Эпоха 3, Средние потери: 0.2525, Точность: 92.10%
# Эпоха 4, Батч 0/220, Потери: 0.0961
# Эпоха 4, Батч 10/220, Потери: 0.1226
# Эпоха 4, Батч 20/220, Потери: 0.1193
# Эпоха 4, Батч 30/220, Потери: 0.1226
# Эпоха 4, Батч 40/220, Потери: 0.1173
# Эпоха 4, Батч 50/220, Потери: 0.1212
# Эпоха 4, Батч 60/220, Потери: 0.1193
# Эпоха 4, Батч 70/220, Потери: 0.1159
# Эпоха 4, Батч 80/220, Потери: 0.1207
# Эпоха 4, Батч 90/220, Потери: 0.1160
# Эпоха 4, Батч 100/220, Потери: 0.1157
# Эпоха 4, Батч 110/220, Потери: 0.1160
# Эпоха 4, Батч 120/220, Потери: 0.1156
# Эпоха 4, Батч 130/220, Потери: 0.1165
# Эпоха 4, Батч 140/220, Потери: 0.1157
# Эпоха 4, Батч 150/220, Потери: 0.1187
# Эпоха 4, Батч 160/220, Потери: 0.1187
# Эпоха 4, Батч 170/220, Потери: 0.1183
# Эпоха 4, Батч 180/220, Потери: 0.1198
# Эпоха 4, Батч 190/220, Потери: 0.1203
# Эпоха 4, Батч 200/220, Потери: 0.1199
# Эпоха 4, Батч 210/220, Потери: 0.1195
# Эпоха 4, Средние потери: 0.1185, Точность: 96.68%
# Эпоха 5, Батч 0/220, Потери: 0.1001
# Эпоха 5, Батч 10/220, Потери: 0.1110
# Эпоха 5, Батч 20/220, Потери: 0.1054
# Эпоха 5, Батч 30/220, Потери: 0.1069
# Эпоха 5, Батч 40/220, Потери: 0.0966
# Эпоха 5, Батч 50/220, Потери: 0.0992
# Эпоха 5, Батч 60/220, Потери: 0.1043
# Эпоха 5, Батч 70/220, Потери: 0.1047
# Эпоха 5, Батч 80/220, Потери: 0.0999
# Эпоха 5, Батч 90/220, Потери: 0.0971
# Эпоха 5, Батч 100/220, Потери: 0.1008
# Эпоха 5, Батч 110/220, Потери: 0.0988
# Эпоха 5, Батч 120/220, Потери: 0.0969
# Эпоха 5, Батч 130/220, Потери: 0.0960
# Эпоха 5, Батч 140/220, Потери: 0.0949
# Эпоха 5, Батч 150/220, Потери: 0.0936
# Эпоха 5, Батч 160/220, Потери: 0.0916
# Эпоха 5, Батч 170/220, Потери: 0.0903
# Эпоха 5, Батч 180/220, Потери: 0.0910
# Эпоха 5, Батч 190/220, Потери: 0.0901
# Эпоха 5, Батч 200/220, Потери: 0.0894
# Эпоха 5, Батч 210/220, Потери: 0.0900
# Эпоха 5, Средние потери: 0.0893, Точность: 97.23%
# Эпоха 6, Батч 0/220, Потери: 0.0482
# Эпоха 6, Батч 10/220, Потери: 0.0701
# Эпоха 6, Батч 20/220, Потери: 0.1154
# Эпоха 6, Батч 30/220, Потери: 0.1119
# Эпоха 6, Батч 40/220, Потери: 0.1105
# Эпоха 6, Батч 50/220, Потери: 0.0955
# Эпоха 6, Батч 60/220, Потери: 0.0879
# Эпоха 6, Батч 70/220, Потери: 0.0813
# Эпоха 6, Батч 80/220, Потери: 0.0757
# Эпоха 6, Батч 90/220, Потери: 0.0743
# Эпоха 6, Батч 100/220, Потери: 0.0736
# Эпоха 6, Батч 110/220, Потери: 0.0747
# Эпоха 6, Батч 120/220, Потери: 0.0780
# Эпоха 6, Батч 130/220, Потери: 0.0788
# Эпоха 6, Батч 140/220, Потери: 0.0768
# Эпоха 6, Батч 150/220, Потери: 0.0754
# Эпоха 6, Батч 160/220, Потери: 0.0785
# Эпоха 6, Батч 170/220, Потери: 0.0783
# Эпоха 6, Батч 180/220, Потери: 0.0779
# Эпоха 6, Батч 190/220, Потери: 0.0789
# Эпоха 6, Батч 200/220, Потери: 0.0775
# Эпоха 6, Батч 210/220, Потери: 0.0789
# Эпоха 6, Средние потери: 0.0789, Точность: 97.42%
# Эпоха 7, Батч 0/220, Потери: 0.0764
# Эпоха 7, Батч 10/220, Потери: 0.0410
# Эпоха 7, Батч 20/220, Потери: 0.0366
# Эпоха 7, Батч 30/220, Потери: 0.0368
# Эпоха 7, Батч 40/220, Потери: 0.0348
# Эпоха 7, Батч 50/220, Потери: 0.0388
# Эпоха 7, Батч 60/220, Потери: 0.0391
# Эпоха 7, Батч 70/220, Потери: 0.0393
# Эпоха 7, Батч 80/220, Потери: 0.0378
# Эпоха 7, Батч 90/220, Потери: 0.0374
# Эпоха 7, Батч 100/220, Потери: 0.0385
# Эпоха 7, Батч 110/220, Потери: 0.0430
# Эпоха 7, Батч 120/220, Потери: 0.0442
# Эпоха 7, Батч 130/220, Потери: 0.0434
# Эпоха 7, Батч 140/220, Потери: 0.0441
# Эпоха 7, Батч 150/220, Потери: 0.0451
# Эпоха 7, Батч 160/220, Потери: 0.0451
# Эпоха 7, Батч 170/220, Потери: 0.0477
# Эпоха 7, Батч 180/220, Потери: 0.0478
# Эпоха 7, Батч 190/220, Потери: 0.0502
# Эпоха 7, Батч 200/220, Потери: 0.0547
# Эпоха 7, Батч 210/220, Потери: 0.0614
# Эпоха 7, Средние потери: 0.0682, Точность: 97.89%
# Эпоха 8, Батч 0/220, Потери: 0.0084
# Эпоха 8, Батч 10/220, Потери: 0.1581
# Эпоха 8, Батч 20/220, Потери: 0.1576
# Эпоха 8, Батч 30/220, Потери: 0.1389
# Эпоха 8, Батч 40/220, Потери: 0.1122
# Эпоха 8, Батч 50/220, Потери: 0.1020
# Эпоха 8, Батч 60/220, Потери: 0.0888
# Эпоха 8, Батч 70/220, Потери: 0.0854
# Эпоха 8, Батч 80/220, Потери: 0.0845
# Эпоха 8, Батч 90/220, Потери: 0.0793
# Эпоха 8, Батч 100/220, Потери: 0.0748
# Эпоха 8, Батч 110/220, Потери: 0.0723
# Эпоха 8, Батч 120/220, Потери: 0.0688
# Эпоха 8, Батч 130/220, Потери: 0.0668
# Эпоха 8, Батч 140/220, Потери: 0.0649
# Эпоха 8, Батч 150/220, Потери: 0.0626
# Эпоха 8, Батч 160/220, Потери: 0.0601
# Эпоха 8, Батч 170/220, Потери: 0.0578
# Эпоха 8, Батч 180/220, Потери: 0.0569
# Эпоха 8, Батч 190/220, Потери: 0.0573
# Эпоха 8, Батч 200/220, Потери: 0.0571
# Эпоха 8, Батч 210/220, Потери: 0.0560
# Эпоха 8, Средние потери: 0.0555, Точность: 98.17%
# Эпоха 9, Батч 0/220, Потери: 0.0283
# Эпоха 9, Батч 10/220, Потери: 0.0374
# Эпоха 9, Батч 20/220, Потери: 0.0254
# Эпоха 9, Батч 30/220, Потери: 0.0220
# Эпоха 9, Батч 40/220, Потери: 0.0196
# Эпоха 9, Батч 50/220, Потери: 0.0177
# Эпоха 9, Батч 60/220, Потери: 0.0178
# Эпоха 9, Батч 70/220, Потери: 0.0212
# Эпоха 9, Батч 80/220, Потери: 0.0252
# Эпоха 9, Батч 90/220, Потери: 0.0254
# Эпоха 9, Батч 100/220, Потери: 0.0237
# Эпоха 9, Батч 110/220, Потери: 0.0241
# Эпоха 9, Батч 120/220, Потери: 0.0239
# Эпоха 9, Батч 130/220, Потери: 0.0242
# Эпоха 9, Батч 140/220, Потери: 0.0258
# Эпоха 9, Батч 150/220, Потери: 0.0262
# Эпоха 9, Батч 160/220, Потери: 0.0262
# Эпоха 9, Батч 170/220, Потери: 0.0251
# Эпоха 9, Батч 180/220, Потери: 0.0242
# Эпоха 9, Батч 190/220, Потери: 0.0233
# Эпоха 9, Батч 200/220, Потери: 0.0224
# Эпоха 9, Батч 210/220, Потери: 0.0219
# Эпоха 9, Средние потери: 0.0214, Точность: 99.53%
# Эпоха 10, Батч 0/220, Потери: 0.0039
# Эпоха 10, Батч 10/220, Потери: 0.0042
# Эпоха 10, Батч 20/220, Потери: 0.0051
# Эпоха 10, Батч 30/220, Потери: 0.0056
# Эпоха 10, Батч 40/220, Потери: 0.0055
# Эпоха 10, Батч 50/220, Потери: 0.0053
# Эпоха 10, Батч 60/220, Потери: 0.0071
# Эпоха 10, Батч 70/220, Потери: 0.0101
# Эпоха 10, Батч 80/220, Потери: 0.0105
# Эпоха 10, Батч 90/220, Потери: 0.0103
# Эпоха 10, Батч 100/220, Потери: 0.0101
# Эпоха 10, Батч 110/220, Потери: 0.0104
# Эпоха 10, Батч 120/220, Потери: 0.0104
# Эпоха 10, Батч 130/220, Потери: 0.0102
# Эпоха 10, Батч 140/220, Потери: 0.0099
# Эпоха 10, Батч 150/220, Потери: 0.0095
# Эпоха 10, Батч 160/220, Потери: 0.0099
# Эпоха 10, Батч 170/220, Потери: 0.0137
# Эпоха 10, Батч 180/220, Потери: 0.0209
# Эпоха 10, Батч 190/220, Потери: 0.0221
# Эпоха 10, Батч 200/220, Потери: 0.0229
# Эпоха 10, Батч 210/220, Потери: 0.0249
# Эпоха 10, Средние потери: 0.0246, Точность: 99.40%

# %%
def evaluate_model():
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for images, labels in test_dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images).logits
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    print(f'Точность на тестовой выборке: {100 * correct / total:.2f}%')

# %%
evaluate_model()
# Out:
# Точность на тестовой выборке: 84.30%

# %%
model_save_path = '/content/drive/MyDrive/Курсовая/skin_lesion_model_25.01.25.pth'
torch.save(model.state_dict(), model_save_path)

# %% [markdown]
# Надо дорабатывать, она переобучена
